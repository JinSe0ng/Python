# %% [markdown]
# # 딕셔너리 (Dictionary)

# %% [markdown]
# # 1 딕셔너리 생성

# %% [markdown]
# ## 1.1 딕셔너리 생성 실습

# %%
score = {'name':'Tom', 'math':80, 'english':70}
score2 = dict(name='Tom', math=80, english=70)

print(score)
print(score2)
# Out:
# {'name': 'Tom', 'math': 80, 'english': 70}
# {'name': 'Tom', 'math': 80, 'english': 70}

# %% [markdown]
# ## 1.2 딕셔너리 특징

# %% [markdown]
# key값으로 활용할 수 있는 자료형 확인

# %%
people = {'name': 'Tom', 'name':'Amy'}
people
# Out:
# {'name': 'Amy'}

# %%
dic_var = {
    'key': 'value',
    1: 'value2',
    1.1: 'value3',
    False: 'value4',
    ('key', 1,1.1,True): 'value5'
}

print(dic_var)
print(list(map(type,dic_var.keys())))
# Out:
# {'key': 'value', 1: 'value2', 1.1: 'value3', False: 'value4', ('key', 1, 1.1, True): 'value5'}
# [<class 'str'>, <class 'int'>, <class 'float'>, <class 'bool'>, <class 'tuple'>]

# %% [markdown]
# value 값으로 활용할 수 있는 자료형 확인 (모든 자료형)

# %% [markdown]
# # 2 키(key)통해 딕셔너리 값(value)에 접근 및 변경

# %% [markdown]
# # 3 딕셔너리 기능 1

# %% [markdown]
# ## 3.1 key가 있는지 확인: in

# %%
print('math' in score)
# Out:
# True

# %%
print('sciece' in score)
# Out:
# False

# %% [markdown]
# ## 3.2 key개수 구하기: len(dict)

# %%
print(len(score))
# Out:
# 3

# %% [markdown]
# ## 3.3 key-value쌍 추가하기: .setdefault(key, value)

# %%
score.setdefault('age', 20)
# Out:
# 20

# %%
score
# Out:
# {'name': 'Tom', 'math': 80, 'english': 70, 'age': 20}

# %% [markdown]
# ## 3.4 key-value 수정하기: .update({key: value})

# %% [markdown]
# # 4 딕셔너리 기능 2

# %% [markdown]
# ## 4.1 key로 항목 삭제 후 삭제된 value 반환: pop(key)

# %%
score = {'name':'Tom', 'math':80, 'english':70}

# %%
score.pop('name')
# Out:
# 'Tom'

# %%
score.keys()
# Out:
# dict_keys(['math', 'english'])

# %%
score.values()
# Out:
# dict_values([80, 70])

# %% [markdown]
# ## 4.2 모든 값 삭제: .clear()

# %%
score.clear()

# %% [markdown]
# ## 4.3 모든 key, value 가져오기: .keys(), values()

# %% [markdown]
# # 5 딕셔너리 할당과 복사

# %% [markdown]
# ## 5.1 딕셔너리 복사

# %% [markdown]
# 1. 복사

# %% [markdown]
# 2. 값 변경

# %% [markdown]
# ## 5.2 중첩 딕셔너리 복사

# %% [markdown]
# 1. 복사

# %% [markdown]
# 2. 값 변경

# %% [markdown]
# # 6 dict() 함수와 시퀀스 객체로 딕셔너리 생성하기 (zip()내장함수)

# %% [markdown]
# ## 6.1 키와 값 한 쌍을 갖는 시퀀스 객체를 요소로 갖는 시퀀스 객체를 생성하여 딕셔너리 자료형으로 만들 수 있음

# %%
my_dict1 = dict([('test',1)])
my_dict2 = dict([('key1','value2'),('key2','value2')])

print(my_dict1)
print(my_dict2)
# Out:
# {'test': 1}
# {'key1': 'value2', 'key2': 'value2'}

# %% [markdown]
# ## 6.2 zip() 내장함수 통해 딕셔너리 생성해보기

# %%
list(zip(['key1','key2'],['value1','value2']))
# Out:
# [('key1', 'value1'), ('key2', 'value2')]

# %%
dict(zip(['key1','key2'],['value1','value2']))
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %% [markdown]
# ## 6.3 응용해보기

# %%
keys = [1,2,3]
values = ['apple','banana','kiwi']

dict(zip(keys, values))
# Out:
# {1: 'apple', 2: 'banana', 3: 'kiwi'}

# %% [markdown]
# # 딕셔너리 실습 01
# [문제] 이름, 나이, 연락처를 받아 딕셔너리를 생성하여 출력해주세요.
#
# [실행] \
# 이름을 입력해주세요: 홍길동 \
# 나이를 입력해주세요: 27 \
# 연락처 입력해주세요: 010-1234-6789
#
# [결과] \
# {‘이름’: ’홍길동’, ‘나이’: ’27’, ‘연락처’: ‘010-6768-7574’}

# %%
name = input()
age = input()
p_num = input()

result  = {'이름' : name, '나이' : age, '연락처':p_num}
result2 = dict(이름=name, 나이=age, 연락처=p_num)

print(result)
print(result2)
# Out:
# {'이름': '홍길도', '나이': '25', '연락처': '01012345678'}
# {'이름': '홍길도', '나이': '25', '연락처': '01012345678'}

# %% [markdown]
# # 딕셔너리 실습 02
#
# [문제] \
# 두 사람의 이름, 나이, 연락처를 받아 두 개의 딕셔너리를 생성 후 리스트에 담아주세요.
#
# [실행] \
# 이름을 입력해주세요: 홍길동 \
# 나이를 입력해주세요: 27 \
# 연락처 입력해주세요: 010-1234-6789 \
# 이름을 입력해주세요: 이몽룡 \
# 나이를 입력해주세요: 30 \
# 연락처 입력해주세요: 010-1122-3344
#
# [결과] \
# [{‘이름’: ’홍길동’, ‘나이’: ’27’, ‘연락처’: ‘010-1234-6789’}, {‘이름’: ’이몽룡’, ‘나이’: 30’, ‘연락처’: ‘010-1122-3344’}]

# %%
# 방법1

name = input()
age = input()
p_num = input()

result1  = {'이름' : name, '나이' : age, '연락처':p_num}

name2 = input()
age2 = input()
p_num2 = input()
result2  = {'이름' : name2, '나이' : age2, '연락처':p_num2}

result = [result1, result2]
print(result)
# Out:
# [{'이름': '홍길동', '나이': '27', '연락처': '01012346789'}, {'이름': '이몽룡', '나이': '30', '연락처': '01011223344'}]

# %%
# 방법2
result = []
result.extend([result1,result2])
print(result)
# Out:
# [{'이름': '홍길동', '나이': '27', '연락처': '01012346789'}, {'이름': '이몽룡', '나이': '30', '연락처': '01011223344'}]

# %%
test = []
test.append(result2)
print(test)
# Out:
# [{'이름': '이몽룡', '나이': '30', '연락처': '01011223344'}]

# %% [markdown]
# # 딕셔너리 실습 03
# [문제]
# input() 함수를 통해 원하는 과일 이름을 입력하면 가격이 출력되는 프로그램을 구현해봅시다.
# - 과일 이름(str)을 key로 만들고 가격(int)을 value로 해서 딕셔너리 자료형을 만듭니다.
# - 사과는 1000원, 바나나는 700원, 오렌지는 1500원, 파인애플은 2000원
#
# [실행 결과] \
# 과일 이름을 입력하세요: 사과 \
# 사과의 가격은 1000원입니다.

# %%
fruit = {'사과': 1000, '바나나':700, '파인애플':2000}

a = input('과일이름을 입력하세요: ')
print(f'{a}의 가격은 {fruit[a]}원 입니다.')
# Out:
# 사과의 가격은 1000원 입니다.

# %% [markdown]
# # 딕셔너리 실습 04
#
# [문제]
# - input() 함수를 통해 이름 값 여럿을 입력 받습니다.
# - 입력 받고 난 후에 이름 순서와 개수를 동일하게 몸무게 값을 입력 받습니다.
# - 이름(str)을 키(key)로, 몸무게(float)를 값(value)으로 하는 딕셔너리 자료형을 만들고 그 결과를 출력해보세요
#
# [실행 결과]
# - 이름을 기입해주세요: 뽀로로 루피 크롱 스누피
# - 몸무게를 입려해주세요: 20.4 16.2 22.3 5.2
# - {'뽀로로': 20.4, '루피': 16.2, }

# %%
names = input('이름을 기입해주세요: ').split()
weights = map(float,input('몸무게를 입력해주세요: ').split())

print(names)
print(weights)

result = dict(zip(names,weights))
print(result)
# Out:
# ['뽀로로', '루피', '크롱', '스누피']
# <map object at 0x107f6eb00>
# {'뽀로로': 20.4, '루피': 16.2, '크롱': 22.3, '스누피': 5.2}

# %%
# Out:
# {'홍': 5.0}
