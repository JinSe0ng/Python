# %% [markdown]
# # Boolean과 논리, 비교연산자

# %% [markdown]
# # 1. Boolean형 확인

# %%
true = '참입니다.'
print(type(true))
print(true)

false = '거짓입니다.'
print(type(false))
print(false)
# Out:
# <class 'str'>
# 참입니다.
# <class 'str'>
# 거짓입니다.

# %% [markdown]
# # 2. 비교 연산자

# %%
print(3 > 1)
print(3 ==1)

print('3 > 1')
# Out:
# True
# False
# 3 > 1

# %%
x = 3 < 1
print (x)
# Out:
# False

# %%
print (10==10)
print (10!=10)
# Out:
# True
# False

# %%
if 10==10:
    print('10과 10은 같습니다.')

print('조건문은 끝났습니다.')
# Out:
# 10과 10은 같습니다.
# 조건문은 끝났습니다.

# %%
if False:
    print('10과 10은 같습니다.')


print('조건문은 끝났습니다.')
# Out:
# 조건문은 끝났습니다.

# %% [markdown]
# # 3. 논리 연산자

# %% [markdown]
# ## 3.1 and

# %%
print(true and true)
# Out:
# 참입니다.

# %%
print(False and true)
# Out:
# False

# %%
print(False and False)
# Out:
# False

# %% [markdown]
# ## 3.2 or

# %%
print(true or true)
print(true or false)
print(false or false)
# Out:
# 참입니다.
# 참입니다.
# 거짓입니다.

# %% [markdown]
# ## 3.3 not

# %%
print( not True)
print(not False)
# Out:
# False
# True

# %% [markdown]
# # 4. 실습01
#
# [문제] 사용자로 점수를 3개 입력 받아모든 점수가 65점 보다 클 경우 True, 점수가 하나라도 65점이 안 넘을 경우 False를 출력하세요.

# %%
a = int(input('첫 번째 점수: '))
b = int(input('두 번째 점수: '))
c = int(input('세 번째 점수: '))

print('a점수: ',a)
print('b점수: ',b)
print('c점수: ',c)

print('결과: ', (a>65)and(b>65)and(c>65))
# Out:
# a점수:  70
# b점수:  56
# c점수:  67
# 결과:  False
