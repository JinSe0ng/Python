# %% [markdown]
# # 조건문 개요

# %% [markdown]
# # 1. 조건문 작성 예제

# %% [markdown]
# 1. x에 정수를 받고 타입 확인해보기

# %%
x = int(input())
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# 2. is를 통해 좌, 우 동일한지 확인해보기

# %%
print(type(x) is int)
# Out:
# True

# %% [markdown]
# 3. 최종적으로 x가 정수일때만 실행되는 코드 작성해보기

# %%
if type(x) is int:
    print('x는 정수입니다.')

print('if문 실행 완료')
# Out:
# x는 정수입니다.
# if문 실행 완료

# %% [markdown]
# # 2. 논리연산자 활용

# %% [markdown]
# # 3. if문과 elif문

# %%
age = 39

if 20 <= age < 30:
    print('20대 입니다.')
elif 30 <= age < 40:
    print('30대 입니다.')

print('조건문이 끝났습니다.')
# Out:
# 30대 입니다.
# 조건문이 끝났습니다.

# %%
#if 문이 True인 경우

age = 26

if 20 <= age < 30:
    print('20대 입니다.')
elif 30 <= age < 40:
    print('30대 입니다.')

print('조건문이 끝났습니다.')
# Out:
# 20대 입니다.
# 조건문이 끝났습니다.

# %% [markdown]
# # 4. if문과 elif문 그리고 else문

# %%
age = 43
if 20 <= age < 30:
    print('20대 입니다.')
elif 30 <= age < 40:
    print('30대 입니다.')
else:
    print('40대 입니다.')

print('조건문이 끝났습니다.')
# Out:
# 40대 입니다.
# 조건문이 끝났습니다.

# %%
score = 86
if score >= 90:
    print('A')
elif score >= 80:
    print('B')
elif score >= 70:
    print('C')
else:
    print('F')

print('조건문이 끝났음')
# Out:
# B
# 조건문이 끝났음

# %% [markdown]
# # 5. 실습 01
# [문제] 물의 온도에 따라 현재 상태를 출력하는 프로그램을 만들려고 함
# - 사용자로부터 물의 온도가 몇인지 입력 받고
# - 100 이상이면 ‘기체로 예상됩니다’를 출력
# - 100보다 작고 0이상이면, ‘액체로 예상됩니다.’를 출력
# - 0보다 작으면 ‘고체로 예상됩니다.’를 출력

# %%
Temp = int(input('현재 물의 온도를 입력해주세요: '))
if 100 <= Temp:
    print('기체로 예상됩니다.')
elif 0 <= Temp < 100:
    print('액체로 예상됩니다.')
else:
    print('고체로 예상됩니다.')

print('조건문이 끝났습니다.')
# Out:
# 액체로 예상됩니다.
# 조건문이 끝났습니다.

# %% [markdown]
# # 6. 실습 02
# - 사용자로부터 아이디를 입력 받습니다.
# - 이 때 아이디가 ’admin’면 ‘최고 관리자, 모든 권한을 갖습니다.’를 출력하고 프로그램 종료.
# - 아이디가 ’admin’이 아니면, 회원 등급을 정수로 받습니다.
# - 만약 회원 레벨이 1~3 사이 값이면, ‘제한적인 권한을 갖습니다’를 출력하고
# - 그렇지 않으면, ‘권한이 없습니다’를 출력 후 프로그램 종료

# %%
a = input('아이디를 입력해주세요: ')
if a == 'admin':
    print('최고 관리자, 모든 권한을 갖습니다.')
elif 1 <= float(a) <= 3:
    print('제한적인 권한을 갖습니다.')
else: 
    print('권한이 없습니다.')
# Out:
# 제한적인 권한을 갖습니다.

# %%
a = input('아이디를 입력해주세요: ')
if a == 'admin':
    print('최고 관리자, 모든 권한을 갖습니다.')
else: 
    grade = int(input('ㅎ회원제 등급을 입력해주세요: '))

    if 1 <= grade <= 3:
         print('제한적인 권한을 갖습니다.')
    else:
        print('권한이 없습니다.')
# Out:
# 제한적인 권한을 갖습니다.

# %% [markdown]
# # 7. 실습 03
# [문제] 일반 시내버스 요금을 받는 프로그램을 만들려고 함
# - 사용자로부터 나이를 입력 받고 나이에 따른 일반 시내버스 요금을 출력하세요.
#     - 성인 (19세 이상)이면 1500원
#     - 청소년 (12~18세)이면 1100원
#     - 어린이(6~7세)면 800원
#     - 미취학 아동은 무료

# %%
a = float(input('나이를 입력해 주세요.: '))
if a >= 19:
    print('1500원')
elif 12<= a <= 18:
    print('1200원')
else:
    print('800원')
# Out:
# 800원

# %% [markdown]
# # 8. pass

# %%
# 잘못된 예
x = 20

if x == 20:
    print('if문의 body입니다.')
    test = 1 + x
    print(test)
    #pass
print('조건문이 끝났습니다.')
# Out:
# if문의 body입니다.
# 21
# 조건문이 끝났습니다.

# %% [markdown]
# # 9. 중첩

# %%
age = int(input())

if age >= 10:
    print('10살 이상')
    if age >= 20:
        print('20살 이상')
        if age >= 30:
            print('30살 이상')
        print('age>=20 구간입니다.')

# %% [markdown]
# # 10. 실습 04
# - 사용자로부터 자연수를 입력 받습니다. 그 숫자에서 50을 뺀 값을 출력하세요.
# - 단, 출력 값의 범위는 0 이상입니다.
# - 50을 뺀 결과가 음수가 될 경우, 0을 출력해야 합니다.

# %%
a = int(input('자연수를 입력해주세요: '))
if a>= 50:
    print(a-50)
else:
    print(0)
# Out:
# 0

# %%
x = int(input())
print('x: ', x)
result = x-50
if result<0:
    result=0
    
print(result)
# Out:
# x:  60
# 10

# %% [markdown]
# # 11. if문과 else문

# %% [markdown]
# # 12. 실습 05
# - 사용자로 부터 자연수를 입력 받습니다.
# - 값이 짝수인지 홀수인지 화면에 출력합니다.

# %%
a = int(input('자연수를 입력해주세요: '))
if a%2 >0:
    print('홀수')
else:
    print('짝수')
# Out:
# 짝수

# %% [markdown]
# # 13. 실습 06
# - A사는 B사에서 C상품 ($10/개) 을 납품합니다. 발주 수량에 따라 수량할인을 고려하여 납품가가 달라집니다.
# - 1000개 미만은 수량할인이 적용되지 않습니다.
# - 1000개부터 1500개 까지 5% 할인, 1500개 초과 2000개까지 10% 할인, 2000개 초과부터는 20% 할인됩니다.
# - 발주 수량을 사용자로부터 입력 받고, 총 발주금액을 출력하는 프로그램을 작성해보세요.
# - 소수점은 할인의 일환으로 버립니다.

# %%
a = int(input('수량을 입력해주세요: '))
print(f'{a}개를 주문하였습니다.')

if a < 1000:
    print( f'10*{a} 원입니다.' )
elif 1000 <=a<1500:
    print(f'9.5*{a} 원입니다.')
elif 1500 <=a<2000:
    print(f'9*{a} 원입니다.')
else:
    print(f'8*{a} 원입니다.')
# Out:
# 1700개를 주문하였습니다.
#  (9*1700) 원입니다.

# %%
a = int(input('수량을 입력해주세요: '))
print(f'{a}개를 주문하였습니다.')

price = 10
rate = 0
order_amount = 0

if 2000 < a:
  rate = 20
elif 1500 <=a< 2000:
  rate = 10
elif 1000<a<=1500:
  rate = 5

total_price = int( a * (100-rate) * 10 * 0.01)
print( f'{total_price} 원 입니다.')
# Out:
# 1200개를 주문하였습니다.
# 11400 원 입니다.

# %% [markdown]
# # 14. 실습 07
# [문제] 주민등록번호 뒷자리를 입력 받아 성별을 확인하는 프로그램을 작성해보기
# - 주민등록번호 뒷자리 7자리 중 맨 앞 번호가 1, 3인 경우는 남자이고, 2, 4인 경우는 여자를 의미
# - 자리수가 7자리가 아니면 ‘자리수를 잘못 입력했습니다.’를 출력
# - 맨 앞 번호가 1, 2, 3, 4가 아니면, ‘잘못된 입력입니다.’를 출력

# %%
a = input('주민등록번호 뒷자리를 입력해주세요: ')

if a[0] == 1 or 3:
    print('남자입니다.')
elif a[0] == 2 or 4:
    print('여자입니다.')
else:
    print('잘못된 입력입니다.')
# Out:
# 남자입니다.

# %%
reg_num = input('주민등록번호 뒷자리를 입력해주세요: ')
print ('주민등록번호 뒷자리를 입력해주세요: ', reg_num ) 

if len(reg_num) != 7:
    print('자리수를 잘못 입력했습니다.')
else:
    fst_num =   int(reg_num[0])
    if fst_num in (1,3):
        print('남자')
    elif fst_num in (2,4):
        print(' 여자')
    else:
        print('잘못된 입력입니다.')
# Out:
# 주민등록번호 뒷자리를 입력해주세요:  1111111
# 남자

# %% [markdown]
# # 15. 실습 08
# [문제] 연도 값을 입력 받아 윤년인지 평년인지를 출력하는 프로그램 작성해보기
# - 연도가 4로 나누어 떨어지는 경우: 윤년
# - 그 밖의 해: 평년
# - 예외
#     - 100으로 나누어 떨어지되 400으로 나누어 떨어지지 않는 해: 평년

# %%
a = int( input('연도를 입력해주세요.: '))
print('연도를 입력해주세요.: ', a)

if a%4 != 0:
    print('평년입니다.')
else:
    if a %400 ==0:
       print('윤년 입니다.')
    elif a%100 ==0:
        print('평년입니다.')
    else:
       print('윤년 입니다.')
# Out:
# 연도를 입력해주세요.:  1024
# 윤년 입니다.

# %%
year = int( input('연도를 입력해주세요.: '))
print('연도를 입력해주세요.: ', year )

if year%4 == 0 and (year%100 !=0 or year%400 ==0):
    print('윤년')
else:
    print('평년')
# Out:
# 연도를 입력해주세요.:  2024
# 윤년
