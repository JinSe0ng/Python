# %% [markdown]
# # 1. 산술연산

# %% [markdown]
# ## 1.1 덧셈

# %%
print(1+2)
# Out:
# 3

# %% [markdown]
# ## 1.2 뺄셈

# %%
print(1-3)
# Out:
# -2

# %% [markdown]
# ## 1.3 곱셈

# %%
print(4*9)
# Out:
# 36

# %% [markdown]
# ## 1.4 나눗셈

# %%
print(48/8)
# Out:
# 6.0

# %% [markdown]
# ## 1.5 나눗셈 (몫)

# %%
print(49//8)
# Out:
# 6

# %% [markdown]
# ## 1.6 나눗셈 (나머지)

# %%
print(49%8)
# Out:
# 1

# %% [markdown]
# ## 1.7 제곱

# %%
print(4**3)
# Out:
# 64

# %% [markdown]
# ## 1.8 괄호 (우선순위)

# %%
print(40/(5-3))
# Out:
# 20.0

# %% [markdown]
# ## 1.9 실습 01

# %% [markdown]
# [문제1] 13 + (22 - 3) x 4 의 결과를 구해보세요.

# %%
print(13+(22-3)*4)
# Out:
# 89

# %% [markdown]
# [문제2] 13 + ((22 - 3) x 4) ÷ 5 의 결과를 구해보세요.

# %%
result = 13 + ((22 - 3) * 4) / 5 
print(result)
# Out:
# 28.2

# %% [markdown]
# # 2. 숫자형 변환

# %% [markdown]
# ## 2.1 정수 -> 실수

# %%
print(float(4))
# Out:
# 4.0

# %% [markdown]
# ## 2.2 실수 -> 정수

# %%
print(int(4.5))
# Out:
# 4
